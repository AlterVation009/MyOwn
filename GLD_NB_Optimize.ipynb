-- %%
-- Out:
-- StatementMeta(, d4e2cdd0-3344-4f20-af52-b232293d06b1, 3, Finished, , Finished)
-- [REQUIRES_SINGLE_PART_NAMESPACE] spark_catalog requires a single-part namespace, but got `DEV_GLD_LH`.`dbo`.
-- org.apache.spark.sql.errors.QueryCompilationErrors$.requiresSinglePartNamespaceError(QueryCompilationErrors.scala:1347)
-- org.apache.spark.sql.execution.datasources.v2.V2SessionCatalog$TableIdentifierHelper.asTableIdentifier(V2SessionCatalog.scala:258)
-- org.apache.spark.sql.execution.datasources.v2.V2SessionCatalog.loadTable(V2SessionCatalog.scala:81)
-- org.apache.spark.sql.connector.catalog.DelegatingCatalogExtension.loadTable(DelegatingCatalogExtension.java:73)
-- org.apache.spark.sql.delta.catalog.DeltaCatalog.super$loadTable(DeltaCatalog.scala:192)
-- org.apache.spark.sql.delta.catalog.DeltaCatalog.$anonfun$loadTable$1(DeltaCatalog.scala:192)
-- org.apache.spark.sql.delta.metering.DeltaLogging.recordFrameProfile(DeltaLogging.scala:169)
-- ...
