-- %%
SELECT COUNT(*)
FROM [DEV_GLD_WH].[dbo].[fact_inventory]
-- Out:
-- DatawarehouseExecuteSqlError: Arithmetic overflow error converting expression to data type int.
-- Statement ID: {9E0E2D78-4E95-4B69-9946-7B1F329B277D} | Query hash: 0x68E4ABD037858DD2 | Distributed request ID: {970A4EFA-9F48-4BD9-942B-8E17EA8FCD01} Data warehouse trace id: b5923b81-91ed-45c8-849f-1ccd4320745e
